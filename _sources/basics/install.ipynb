# %% [markdown]
# # Installation
#
# Install the latest version of ekorpkit:
#
# ```bash
# pip install -U ekorpkit
# ```
#
# To install all extra dependencies,
#
# ```bash
# pip install ekorpkit[all]
# ```
#
# To install all extra dependencies, exhaustively, (not recommended)
#
# ```bash
# pip install ekorpkit[exhaustive]
# ```
#
# ## Extra dependencies
#
# ### List of extra dependency sets

# %%
from ekorpkit import eKonf
eKonf.dependencies()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ekorpkit import eKonf
#       2 eKonf.dependencies()
#
# ModuleNotFoundError: No module named 'ekorpkit'

# %% [markdown]
# ### List of libraries in each dependency set

# %%
from ekorpkit import eKonf
eKonf.dependencies("tokenize")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ekorpkit import eKonf
#       2 eKonf.dependencies("tokenize")
#
# ModuleNotFoundError: No module named 'ekorpkit'

# %%
eKonf.dependencies("dataset")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 eKonf.dependencies("dataset")
#
# NameError: name 'eKonf' is not defined

# %%
eKonf.dependencies("model")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 eKonf.dependencies("model")
#
# NameError: name 'eKonf' is not defined

# %%
eKonf.dependencies("visualize")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 eKonf.dependencies("visualize")
#
# NameError: name 'eKonf' is not defined

# %%
eKonf.dependencies("all")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 eKonf.dependencies("all")
#
# NameError: name 'eKonf' is not defined

# %% [markdown]
# ### self-upgrade of ekorpkit

# %%
eKonf.upgrade(
  prelease=True, 
  quiet=True, 
  verbose=True, 
  force_reinstall=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 eKonf.upgrade(
#       2   prelease=True,
#       3   quiet=True,
#       4   verbose=True,
#       5   force_reinstall=False)
#
# NameError: name 'eKonf' is not defined
